# %%
import pandas as pd

# %%
df_students = pd.read_csv('students.csv')
students = df_students.dropna().drop_duplicates() # without Null and duplicates

df_teachers = pd.read_csv('teachers.csv')
teachers = df_teachers.dropna().drop_duplicates()  # without Null and duplicates

df_courses = pd.read_csv('courses.csv')
courses = df_courses.dropna().drop_duplicates() # without Null and duplicates

df_student_course = pd.read_csv('student_course.csv')
student_course = df_student_course.dropna().drop_duplicates()  # without Null and duplicates

# %%
import matplotlib.pyplot as plt
display(students)
print( '1 ) -')
male,female= list(students['gender'].value_counts())

plt.bar(['Male', 'Female'], [male, female], color='b')
plt.title("Students by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
students['gender'].value_counts()
# Out:
#       id  first_name  last_name  gender   age       city          education  \
# 0      1      Birgit  Mackriell  Female  15.0      Haifa       No education
# 1      2  Cristionna    Ferrick  Female  32.0  Bnei Brak        High school
# 3      4       Jonis      Iston  Female  40.0  Jerusalem        High school
# 4      5         Dex    Goodson    Male  43.0      Haifa  Bachelor's degree
# 5      6      Marysa    Ovenden  Female  24.0      Haifa        High school
# ..   ...         ...        ...     ...   ...        ...                ...
# 494  495      Lucien  Spreckley    Male  29.0   Tel Aviv        High school
# 495  496      Karoly   Ferreres  Female  29.0      Haifa        High school
# 496  497      Rivkah   Androlli  Female  43.0      Haifa       No education
# 497  498  Melisandra     Screen  Female  34.0      Haifa        High school
# 499  500      Gillan     Terram  Female  34.0      Haifa  Bachelor's degree
#
#                           email
# ...

# %%
print(' 2) -')
age =list(students['age'])

plt.hist(age, bins=15, color='b', alpha=0.7)
plt.title('Histogram')
plt.show()
# Out:
#  2) -

# %%
print(' 3) - ')
display(courses)
course_type= dict(courses['course_name'].value_counts())
print(course_type)
c_keys = [k for k in course_type.keys()]
print(c_keys)
c_values = [v for v in course_type.values()]
print(c_values)

plt.figure(figsize=(10, 6)) # larger the page because the letters of the name course not readble
plt.bar(c_keys,c_values, color='b')
plt.title("Number of courses")
plt.xlabel("courses")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
#  3) -
#     course_id           course_name              course_category  teacher_id  \
# 0           1  Full Stack Developer         Software Development        30.0
# 2           3       Product Manager  Product & Business Strategy        14.0
# 3           4          AI Developer         Software Development        16.0
# 4           5       DevOps Engineer         Software Development        21.0
# 5           6          AI Developer         Software Development         7.0
# 7           8          AI Developer         Software Development        14.0
# 8           9          AI Developer         Software Development         7.0
# 9          10       DevOps Engineer         Software Development        10.0
# 10         11                 Cyber      Data Science & Security         9.0
# 11         12                 Cyber      Data Science & Security        20.0
# 12         13  Full Stack Developer         Software Development        35.0
# ...

# %%
print("4 ) -")

city_count = students[['city']].value_counts()
city_max = city_count.idxmax()
city_min = city_count.idxmin()
display("City with max students", city_max)
display("City with min students", city_min)
# Out:
# 'City with max students'
# ('Tel Aviv',)
# 'City with min students'
# ('Rishon LeZion',)

# %%
print('5 ) -')
uniqe_courses = courses.groupby('course_category')['course_name'].unique()
table_uniqe_courses =uniqe_courses.reset_index()
table_uniqe_courses
# Out:
# 5 ) -
#                course_category  \
# 0      Data Science & Security
# 1  Product & Business Strategy
# 2         Software Development
#
#                                          course_name
# 0                                            [Cyber]
# 1                                  [Product Manager]
# 2  [Full Stack Developer, AI Developer, DevOps En...
